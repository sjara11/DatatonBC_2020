# %% [markdown]
# #Script de Carga - Transformación - Imputaciones - Descarga

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import seaborn as sns
# %matplotlib inline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from math import sqrt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Datos Train

# %% [markdown]
# ###Carga de los datos de train

# %%
#Carga de los nombres de las columnas
headers = np.loadtxt('/content/drive/MyDrive/DATATON/header.txt', dtype =str, delimiter=',')
headers
# Out:
# array(['periodo', 'id_cli', 'fecha_nacimiento', 'edad', 'genero',
#        'estado_civil', 'nivel_academico', 'profesion', 'ocupacion',
#        'tipo_vivienda', 'ult_actual', 'categoria', 'codigo_ciiu',
#        'ind_mora_vigente', 'cartera_castigada', 'ciudad_residencia',
#        'departamento_residencia', 'ciudad_laboral',
#        'departamento_laboral', 'rechazo_credito', 'mora_max',
#        'cant_moras_30_ult_12_meses', 'cant_moras_60_ult_12_meses',
#        'cant_moras_90_ult_12_meses', 'cupo_total_tc', 'tenencia_tc',
#        'cuota_tc_bancolombia', 'tiene_consumo', 'tiene_crediagil',
#        'nro_tot_cuentas', 'ctas_activas', 'tiene_ctas_activas',
#        'ctas_embargadas', 'tiene_ctas_embargadas', 'pension_fopep',
#        'cuota_cred_hipot', 'tiene_cred_hipo_1', 'tiene_cred_hipo_2',
#        'mediana_nom3', 'mediana_pen3', 'ingreso_nompen', 'cat_ingreso',
#        'ingreso_final', 'cant_mora_30_tdc_ult_3m_sf',
# ...

# %%
# !unzip "/content/drive/MyDrive/DATATON/Dataton_train_1.zip"
# Out:
# Archive:  /content/drive/MyDrive/DATATON/Dataton_train_1.zip
#   inflating: Dataton_train_1.csv

# %%
# %%time
#Carga de los datos

datos = pd.read_csv('/content/Dataton_train_1.csv',quotechar='"', names = headers, iterator=True, chunksize=100000, nrows = 5000000)
datos = pd.concat(datos, ignore_index=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py:1193: DtypeWarning: Columns (3,11,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code, glob, local_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py:1193: DtypeWarning: Columns (3,11,29,30,32,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code, glob, local_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py:1193: DtypeWarning: Columns (3,29,30,32,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code, glob, local_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py:1193: DtypeWarning: Columns (3,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code, glob, local_ns)
# ...

# %%
#Tomar la muestra representativa
#datos = datos.sample(5000000,random_state = np.random)

# %% [markdown]
# ###Transformación

# %%
#Correción del campo ciudad residencia
import re
datos['ciudad_residencia'] = datos['ciudad_residencia'].apply(lambda x: x.strip())
datos['ciudad_residencia'] = datos['ciudad_residencia'].apply(lambda x: re.sub(r'[#]','Ñ',x))

datos['departamento_residencia'] = datos['departamento_residencia'].apply(lambda x: x.strip())
datos['departamento_residencia'] = datos['departamento_residencia'].apply(lambda x: re.sub(r'[#]','Ñ',x))

datos['ciudad_laboral'] = datos['ciudad_laboral'].apply(lambda x: x.strip())
datos['ciudad_laboral'] = datos['ciudad_laboral'].apply(lambda x: re.sub(r'[#]','Ñ',x))

datos['departamento_laboral'] = datos['departamento_laboral'].apply(lambda x: x.strip())
datos['departamento_laboral'] = datos['departamento_laboral'].apply(lambda x: re.sub(r'[#]','Ñ',x))

# %%
#Correccion de variables  Object y asignacion de tipo a la variable
datos['edad']=datos['edad'].replace('\\N', np.NaN)
datos['genero']=datos['genero'].replace(' ', np.NaN)
datos['estado_civil']=datos['estado_civil'].replace('\\N', np.NaN)
datos['nivel_academico']=datos['nivel_academico'].replace('SIN INFORMACION', np.NaN)
datos['profesion']=datos['profesion'].replace('\\N', np.NaN)
datos['ocupacion']=datos['ocupacion'].replace('\\N', np.NaN)
datos['ocupacion']=datos['ocupacion'].replace('Vacío', np.NaN)
datos['tipo_vivienda']=datos['tipo_vivienda'].replace('\\N', np.NaN)
datos['categoria']=datos['categoria'].replace('\\N', np.NaN)
datos['ind_mora_vigente']=datos['ind_mora_vigente'].replace('\\N', np.NaN)
datos['cartera_castigada']=datos['cartera_castigada'].replace('\\N', np.NaN)
datos['ciudad_residencia']=datos['ciudad_residencia'].replace('\\N', np.NaN)
datos['ciudad_residencia']=datos['ciudad_residencia'].replace('SIN INFORMACION', np.NaN)
datos['departamento_residencia']=datos['departamento_residencia'].replace('\\N', np.NaN)
datos['departamento_residencia']=datos['departamento_residencia'].replace('SIN INFORMACION', np.NaN)
datos['ciudad_laboral']=datos['ciudad_laboral'].replace('\\N', np.NaN)
datos['ciudad_laboral']=datos['ciudad_laboral'].replace('SIN INFORMACION', np.NaN)
datos['departamento_laboral']=datos['departamento_laboral'].replace('\\N', np.NaN)
datos['departamento_laboral']=datos['departamento_laboral'].replace('SIN INFORMACION', np.NaN)
datos['rechazo_credito']=datos['rechazo_credito'].replace('\\N', np.NaN)
datos['mora_max']=datos['mora_max'].replace('\\N', np.NaN)
datos['cant_moras_30_ult_12_meses']=datos['cant_moras_30_ult_12_meses'].replace('\\N', np.NaN)
datos['cant_moras_60_ult_12_meses']=datos['cant_moras_60_ult_12_meses'].replace('\\N', np.NaN)
datos['cant_moras_90_ult_12_meses']=datos['cant_moras_90_ult_12_meses'].replace('\\N', np.NaN )

datos['tiene_consumo']=datos['tiene_consumo'].replace('\\N', np.NaN )
datos['tiene_crediagil']=datos['tiene_crediagil'].replace('\\N', np.NaN )
datos['tiene_ctas_activas']=datos['tiene_ctas_activas'].replace('\\N', np.NaN )
datos['tiene_ctas_embargadas']=datos['tiene_ctas_embargadas'].replace('\\N', np.NaN )
datos['pension_fopep']=datos['pension_fopep'].replace('\\N', np.NaN)
datos['tiene_cred_hipo_1']=datos['tiene_cred_hipo_1'].replace('\\N', np.NaN)
datos['tiene_cred_hipo_2']=datos['tiene_cred_hipo_2'].replace('\\N', np.NaN )


datos['nro_tot_cuentas']=datos['nro_tot_cuentas'].replace('\\N', np.NaN )
datos['ctas_activas']=datos['ctas_activas'].replace('\\N', np.NaN )
datos['ctas_embargadas']=datos['ctas_embargadas'].replace('\\N', np.NaN )
datos['ind']=datos['ind'].replace('\\N', np.NaN )

datos['cuota_cred_hipot']=datos['cuota_cred_hipot'].replace('\\N', np.NaN )
datos['cat_ingreso']=datos['cat_ingreso'].replace('\\N', np.NaN )
datos['ingreso_final']=datos['ingreso_final'].replace('\\N', np.NaN )
datos['cant_mora_30_tdc_ult_3m_sf']=datos['cant_mora_30_tdc_ult_3m_sf'].replace('\\N', np.NaN )
datos['cant_mora_30_consum_ult_3m_sf']=datos['cant_mora_30_consum_ult_3m_sf'].replace('\\N', np.NaN )
datos['cant_oblig_tot_sf']=datos['cant_oblig_tot_sf'].replace('\\N', np.NaN )
datos['cant_cast_ult_12m_sr']=datos['cant_cast_ult_12m_sr'].replace('\\N', np.NaN) 
datos['rep_calif_cred']=datos['rep_calif_cred'].replace('SIN INFO', np.NaN )
datos['pol_centr_ext']=datos['pol_centr_ext'].replace('\\N', np.NaN )
datos['convenio_lib']=datos['convenio_lib'].replace('\\N', np.NaN)
datos['ingreso_nomina']=datos['ingreso_nomina'].replace('\\N', np.NaN )
datos['ingreso_segurida_social']=datos['ingreso_segurida_social'].replace('\\N', np.NaN )

# %%
#Correcion variable pol_centr_ext
datos['pol_centr_ext'] = datos['pol_centr_ext'].astype(float)
datos.loc[datos['pol_centr_ext']>= 1 ,'pol_centr_ext'] = '1'

# %%
#Correccion variable convenio
datos.loc[datos['convenio_lib'].notnull(),'convenio_lib'] = 'SI'

# %%
#Correccion variable periodo oor PANDEMIA
datos.loc[datos['periodo'] <= 202003,'periodo'] = 0
datos.loc[datos['periodo'] > 202003,'periodo'] = 1

# %%
#Cambiar tipo de datos a las variables string
datos['categoria'] = datos['categoria'].astype('string')
datos['genero'] = datos['genero'].astype('string')
datos['estado_civil']= datos['estado_civil'].astype('string')
datos['nivel_academico']= datos['nivel_academico'].astype('string')
datos['profesion']= datos['profesion'].astype('string')
datos['ocupacion']= datos['ocupacion'].astype('string')
datos['tipo_vivienda']= datos['tipo_vivienda'].astype('string')
datos['ind_mora_vigente'] = datos['ind_mora_vigente'].astype('string')
datos['cartera_castigada']= datos['cartera_castigada'].astype('string')
datos['ciudad_residencia']= datos['ciudad_residencia'].astype('string')
datos['ciudad_laboral']= datos['ciudad_laboral'].astype('string')
datos['departamento_residencia'] = datos['departamento_residencia'].astype('string')
datos['departamento_laboral'] = datos['departamento_laboral'].astype('string')
datos['rechazo_credito'] = datos['rechazo_credito'].astype('string')
datos['tenencia_tc'] = datos['tenencia_tc'].astype('string')
datos['tiene_consumo']  = datos['tiene_consumo'].astype('string')
datos['tiene_crediagil'] = datos['tiene_crediagil'].astype('string')
datos['tiene_ctas_activas'] = datos['tiene_ctas_activas'].astype('string')
datos['tiene_ctas_embargadas'] = datos['tiene_ctas_embargadas'].astype('string')
datos['pension_fopep'] = datos['pension_fopep'].astype('string')
datos['tiene_cred_hipo_1'] = datos['tiene_cred_hipo_1'].astype('string')
datos['tiene_cred_hipo_2'] = datos['tiene_cred_hipo_2'].astype('string')
datos['cat_ingreso'] = datos['cat_ingreso'].astype('string')
datos['rep_calif_cred'] = datos['rep_calif_cred'].astype('string')
datos['convenio_lib'] = datos['convenio_lib'].astype('string')

# %%
#Cambiar tipo de datos a las variables numericas
datos['edad'] = datos['edad'].astype(float)
datos['mora_max'] = datos['mora_max'].astype(float)
datos['cant_moras_30_ult_12_meses'] = datos['cant_moras_30_ult_12_meses'].astype(float)
datos['cant_moras_60_ult_12_meses'] = datos['cant_moras_60_ult_12_meses'].astype(float)
datos['cant_moras_90_ult_12_meses'] = datos['cant_moras_90_ult_12_meses'].astype(float)
datos['nro_tot_cuentas'] = datos['nro_tot_cuentas'].astype(float)
datos['ctas_activas'] = datos['ctas_activas'].astype(float)
datos['ctas_embargadas'] = datos['ctas_embargadas'].astype(float)
datos['ind'] = datos['ind'].astype(float)
datos['cuota_cred_hipot'] = datos['cuota_cred_hipot'].astype(float)
datos['ingreso_final'] = datos['ingreso_final'].astype(float)
datos['cant_mora_30_tdc_ult_3m_sf'] = datos['cant_mora_30_tdc_ult_3m_sf'].astype(float)
datos['cant_mora_30_consum_ult_3m_sf'] = datos['cant_mora_30_consum_ult_3m_sf'].astype(float)
datos['cant_oblig_tot_sf'] = datos['cant_oblig_tot_sf'].astype(float)
datos['cant_cast_ult_12m_sr'] = datos['cant_cast_ult_12m_sr'].astype(float)
datos['ingreso_nomina'] = datos['ingreso_nomina'].astype(float)
datos['ingreso_segurida_social'] = datos['ingreso_segurida_social'].astype(float)

# %% [markdown]
# ###Imputación

# %%
#imputaciones con la moda (criterio: menos del 30% faltante)
datos.loc[datos['estado_civil'].isna() == True, 'estado_civil'] = datos['estado_civil'].mode()[0]
datos.loc[datos['edad'].isna() == True, 'edad'] = datos['edad'].mode()[0]
datos.loc[datos['nivel_academico'].isna() == True, 'nivel_academico'] = datos['nivel_academico'].mode()[0]
datos.loc[datos['profesion'].isna() == True, 'profesion'] = datos['profesion'].mode()[0]
datos.loc[datos['ocupacion'].isna() == True, 'ocupacion'] = datos['ocupacion'].mode()[0]
datos.loc[datos['categoria'].isna() == True, 'categoria'] = datos['categoria'].mode()[0]
datos.loc[datos['ind_mora_vigente'].isna() == True, 'ind_mora_vigente'] = datos['ind_mora_vigente'].mode()[0]
datos.loc[datos['cartera_castigada'].isna() == True, 'cartera_castigada'] = datos['cartera_castigada'].mode()[0]
datos.loc[datos['mora_max'].isna() == True, 'mora_max'] = datos['mora_max'].mode()[0]
datos.loc[datos['cant_moras_30_ult_12_meses'].isna() == True, 'cant_moras_30_ult_12_meses'] = datos['cant_moras_30_ult_12_meses'].mode()[0]
datos.loc[datos['cant_moras_60_ult_12_meses'].isna() == True, 'cant_moras_60_ult_12_meses'] = datos['cant_moras_60_ult_12_meses'].mode()[0]
datos.loc[datos['cant_moras_90_ult_12_meses'].isna() == True, 'cant_moras_90_ult_12_meses'] = datos['cant_moras_90_ult_12_meses'].mode()[0]
datos.loc[datos['nro_tot_cuentas'].isna() == True, 'nro_tot_cuentas'] = datos['nro_tot_cuentas'].mode()[0]
datos.loc[datos['ctas_activas'].isna() == True, 'ctas_activas'] = datos['ctas_activas'].mode()[0]
datos.loc[datos['tiene_ctas_activas'].isna() == True, 'tiene_ctas_activas'] = datos['tiene_ctas_activas'].mode()[0]
datos.loc[datos['ctas_embargadas'].isna() == True, 'ctas_embargadas'] = datos['ctas_embargadas'].mode()[0]
datos.loc[datos['ingreso_final'].isna() == True, 'ingreso_final'] = datos['ingreso_final'].mode()[0]
datos.loc[datos['cant_mora_30_tdc_ult_3m_sf'].isna() == True, 'cant_mora_30_tdc_ult_3m_sf'] = datos['cant_mora_30_tdc_ult_3m_sf'].mode()[0]
datos.loc[datos['cant_mora_30_consum_ult_3m_sf'].isna() == True, 'cant_mora_30_consum_ult_3m_sf'] = datos['cant_mora_30_consum_ult_3m_sf'].mode()[0]
datos.loc[datos['cant_oblig_tot_sf'].isna() == True, 'cant_oblig_tot_sf'] = datos['cant_oblig_tot_sf'].mode()[0]
datos.loc[datos['cant_cast_ult_12m_sr'].isna() == True, 'cant_cast_ult_12m_sr'] = datos['cant_cast_ult_12m_sr'].mode()[0]
datos.loc[datos['ind'].isna() == True, 'ind'] = datos['ind'].mode()[0]
datos.loc[datos['rep_calif_cred'].isna() == True, 'rep_calif_cred'] = datos['rep_calif_cred'].mode()[0]
datos.loc[datos['pol_centr_ext'].isna() == True, 'pol_centr_ext'] = datos['pol_centr_ext'].mode()[0]
datos.loc[datos['departamento_residencia'].isna() == True, 'departamento_residencia'] = datos['departamento_residencia'].mode()[0]


#imputacion con una costante para flags y por su importancia
datos.loc[datos['tiene_consumo'].isna() == True, 'tiene_consumo'] = '-1'
datos.loc[datos['tiene_crediagil'].isna() == True, 'tiene_crediagil'] = '-1'
datos.loc[datos['tiene_ctas_embargadas'].isna() == True, 'tiene_ctas_embargadas'] = '-1'
datos.loc[datos['pension_fopep'].isna() == True, 'pension_fopep'] = '-1'
datos.loc[datos['cuota_cred_hipot'].isna() == True, 'cuota_cred_hipot'] = 0
datos.loc[datos['tiene_cred_hipo_1'].isna() == True, 'tiene_cred_hipo_1'] = '-1'
datos.loc[datos['tiene_cred_hipo_2'].isna() == True, 'tiene_cred_hipo_2'] = '-1'

#imputacion con la moda pero con altos valores faltantes e importancia. NOTA:pendiente si se imputan con KNN
datos.loc[datos['cat_ingreso'].isna() == True, 'cat_ingreso'] = datos['cat_ingreso'].mode()[0]
datos.loc[datos['ingreso_nomina'].isna() == True, 'ingreso_nomina'] = datos['ingreso_nomina'].mode()[0]
datos.loc[datos['ingreso_segurida_social'].isna() == True, 'ingreso_segurida_social'] = datos['ingreso_segurida_social'].mode()[0]
datos.loc[datos['tipo_vivienda'].isna() == True, 'tipo_vivienda'] = datos['tipo_vivienda'].mode()[0]

# %%
#Cambiar tipo de datos a las variables string a Category
datos['categoria'] = datos['categoria'].astype('category')
datos['genero'] = datos['genero'].astype('category')
datos['estado_civil']= datos['estado_civil'].astype('category')
datos['nivel_academico']= datos['nivel_academico'].astype('category')
datos['profesion']= datos['profesion'].astype('category')
datos['ocupacion']= datos['ocupacion'].astype('category')
datos['tipo_vivienda']= datos['tipo_vivienda'].astype('category')
datos['ind_mora_vigente'] = datos['ind_mora_vigente'].astype('category')
datos['cartera_castigada']= datos['cartera_castigada'].astype('category')
datos['departamento_residencia'] = datos['departamento_residencia'].astype('category')

#Borradas en la imputacion
datos['ciudad_residencia']= datos['ciudad_residencia'].astype('category')
datos['ciudad_laboral']= datos['ciudad_laboral'].astype('category')
datos['departamento_laboral'] = datos['departamento_laboral'].astype('category')
datos['convenio_lib'] = datos['convenio_lib'].astype('category')

datos['rechazo_credito'] = datos['rechazo_credito'].astype('category')
datos['tenencia_tc'] = datos['tenencia_tc'].astype('category')
datos['tiene_ctas_activas'] = datos['tiene_ctas_activas'].astype('category')

#2da Iteracion
datos['tiene_consumo']  = datos['tiene_consumo'].astype('category')
datos['tiene_crediagil'] = datos['tiene_crediagil'].astype('category')
datos['tiene_ctas_embargadas'] = datos['tiene_ctas_embargadas'].astype('category')
datos['pension_fopep'] = datos['pension_fopep'].astype('category')
datos['tiene_cred_hipo_1'] = datos['tiene_cred_hipo_1'].astype('category')
datos['tiene_cred_hipo_2'] = datos['tiene_cred_hipo_2'].astype('category')


datos['cat_ingreso'] = datos['cat_ingreso'].astype('category')
datos['rep_calif_cred'] = datos['rep_calif_cred'].astype('category')

# %% [markdown]
# ###Descarga

# %%
#Guardar los datos de train limpios
datos.to_csv('/content/drive/MyDrive/DATATON/Dataset_limpios/train_limpio.csv')

# %% [markdown]
# ## Datos Test

# %% [markdown]
# ###Carga de los datos test

# %%
# !unzip "/content/drive/MyDrive/DATATON/dt2020_base_evaluar.zip"
# Out:
# Archive:  /content/drive/MyDrive/DATATON/dt2020_base_evaluar.zip
#   inflating: dt2020_base_evaluar.csv

# %%
#Importacion del set de test
datos_kaggle = pd.read_csv('/content/dt2020_base_evaluar.csv',quotechar='"')

# %% [markdown]
# ###Transformación

# %%
#Correción del campo ciudad residencia
import re
datos_kaggle['ciudad_residencia'] = datos_kaggle.loc[datos_kaggle['ciudad_residencia'].notnull(),'ciudad_residencia'].apply(lambda x: x.strip())
datos_kaggle['ciudad_residencia'] = datos_kaggle.loc[datos_kaggle['ciudad_residencia'].notnull(),'ciudad_residencia'].apply(lambda x: re.sub(r'[#]','Ñ',x))
datos_kaggle['departamento_residencia'] = datos_kaggle.loc[datos_kaggle['departamento_residencia'].notnull(),'departamento_residencia'].apply(lambda x: x.strip())
datos_kaggle['departamento_residencia'] = datos_kaggle.loc[datos_kaggle['departamento_residencia'].notnull(),'departamento_residencia'].apply(lambda x: re.sub(r'[#]','Ñ',x))
datos_kaggle['ciudad_laboral'] = datos_kaggle.loc[datos_kaggle['ciudad_laboral'].notnull(),'ciudad_laboral'].apply(lambda x: x.strip())
datos_kaggle['ciudad_laboral'] = datos_kaggle.loc[datos_kaggle['ciudad_laboral'].notnull(),'ciudad_laboral'].apply(lambda x: re.sub(r'[#]','Ñ',x))
datos_kaggle['departamento_laboral'] = datos_kaggle.loc[datos_kaggle['departamento_laboral'].notnull(),'departamento_laboral'].apply(lambda x: x.strip())
datos_kaggle['departamento_laboral'] = datos_kaggle.loc[datos_kaggle['departamento_laboral'].notnull(),'departamento_laboral'].apply(lambda x: re.sub(r'[#]','Ñ',x))

# %%
#Correccion de variables  Object y asignacion de tipo a la variable
datos_kaggle['edad']=datos_kaggle['edad'].replace('\\N', np.NaN)
datos_kaggle['genero']=datos_kaggle['genero'].replace(' ', np.NaN)
datos_kaggle['estado_civil']=datos_kaggle['estado_civil'].replace('\\N', np.NaN)
datos_kaggle['nivel_academico']=datos_kaggle['nivel_academico'].replace('SIN INFORMACION', np.NaN)
datos_kaggle['profesion']=datos_kaggle['profesion'].replace('\\N', np.NaN)
datos_kaggle['ocupacion']=datos_kaggle['ocupacion'].replace('\\N', np.NaN)
datos_kaggle['ocupacion']=datos_kaggle['ocupacion'].replace('Vacío', np.NaN)
datos_kaggle['tipo_vivienda']=datos_kaggle['tipo_vivienda'].replace('\\N', np.NaN)
datos_kaggle['categoria']=datos_kaggle['categoria'].replace('\\N', np.NaN)
datos_kaggle['ind_mora_vigente']=datos_kaggle['ind_mora_vigente'].replace('\\N', np.NaN)
datos_kaggle['cartera_castigada']=datos_kaggle['cartera_castigada'].replace('\\N', np.NaN)
datos_kaggle['ciudad_residencia']=datos_kaggle['ciudad_residencia'].replace('\\N', np.NaN)
datos_kaggle['ciudad_residencia']=datos_kaggle['ciudad_residencia'].replace('SIN INFORMACION', np.NaN)
datos_kaggle['departamento_residencia']=datos_kaggle['departamento_residencia'].replace('\\N', np.NaN)
datos_kaggle['departamento_residencia']=datos_kaggle['departamento_residencia'].replace('SIN INFORMACION', np.NaN)
datos_kaggle['ciudad_laboral']=datos_kaggle['ciudad_laboral'].replace('\\N', np.NaN)
datos_kaggle['ciudad_laboral']=datos_kaggle['ciudad_laboral'].replace('SIN INFORMACION', np.NaN)
datos_kaggle['departamento_laboral']=datos_kaggle['departamento_laboral'].replace('\\N', np.NaN)
datos_kaggle['departamento_laboral']=datos_kaggle['departamento_laboral'].replace('SIN INFORMACION', np.NaN)
datos_kaggle['rechazo_credito']=datos_kaggle['rechazo_credito'].replace('\\N', np.NaN)
datos_kaggle['mora_max']=datos_kaggle['mora_max'].replace('\\N', np.NaN)
datos_kaggle['cant_moras_30_ult_12_meses']=datos_kaggle['cant_moras_30_ult_12_meses'].replace('\\N', np.NaN)
datos_kaggle['cant_moras_60_ult_12_meses']=datos_kaggle['cant_moras_60_ult_12_meses'].replace('\\N', np.NaN)
datos_kaggle['cant_moras_90_ult_12_meses']=datos_kaggle['cant_moras_90_ult_12_meses'].replace('\\N', np.NaN )

datos_kaggle['tiene_consumo']=datos_kaggle['tiene_consumo'].replace('\\N', np.NaN )
datos_kaggle['tiene_crediagil']=datos_kaggle['tiene_crediagil'].replace('\\N', np.NaN )
datos_kaggle['tiene_ctas_activas']=datos_kaggle['tiene_ctas_activas'].replace('\\N', np.NaN )
datos_kaggle['tiene_ctas_embargadas']=datos_kaggle['tiene_ctas_embargadas'].replace('\\N', np.NaN )
datos_kaggle['pension_fopep']=datos_kaggle['pension_fopep'].replace('\\N', np.NaN)
datos_kaggle['tiene_cred_hipo_1']=datos_kaggle['tiene_cred_hipo_1'].replace('\\N', np.NaN)
datos_kaggle['tiene_cred_hipo_2']=datos_kaggle['tiene_cred_hipo_2'].replace('\\N', np.NaN )


datos_kaggle['nro_tot_cuentas']=datos_kaggle['nro_tot_cuentas'].replace('\\N', np.NaN )
datos_kaggle['ctas_activas']=datos_kaggle['ctas_activas'].replace('\\N', np.NaN )
datos_kaggle['ctas_embargadas']=datos_kaggle['ctas_embargadas'].replace('\\N', np.NaN )
datos_kaggle['ind']=datos_kaggle['ind'].replace('\\N', np.NaN )

datos_kaggle['cuota_cred_hipot']=datos_kaggle['cuota_cred_hipot'].replace('\\N', np.NaN )
datos_kaggle['cat_ingreso']=datos_kaggle['cat_ingreso'].replace('\\N', np.NaN )
datos_kaggle['ingreso_final']=datos_kaggle['ingreso_final'].replace('\\N', np.NaN )
datos_kaggle['cant_mora_30_tdc_ult_3m_sf']=datos_kaggle['cant_mora_30_tdc_ult_3m_sf'].replace('\\N', np.NaN )
datos_kaggle['cant_mora_30_consum_ult_3m_sf']=datos_kaggle['cant_mora_30_consum_ult_3m_sf'].replace('\\N', np.NaN )
datos_kaggle['cant_oblig_tot_sf']=datos_kaggle['cant_oblig_tot_sf'].replace('\\N', np.NaN )
datos_kaggle['cant_cast_ult_12m_sr']=datos_kaggle['cant_cast_ult_12m_sr'].replace('\\N', np.NaN) 
datos_kaggle['rep_calif_cred']=datos_kaggle['rep_calif_cred'].replace('SIN INFO', np.NaN )
datos_kaggle['pol_centr_ext']=datos_kaggle['pol_centr_ext'].replace('\\N', np.NaN )
datos_kaggle['convenio_lib']=datos_kaggle['convenio_lib'].replace('\\N', np.NaN)
datos_kaggle['ingreso_nomina']=datos_kaggle['ingreso_nomina'].replace('\\N', np.NaN )
datos_kaggle['ingreso_segurida_social']=datos_kaggle['ingreso_segurida_social'].replace('\\N', np.NaN )

# %%
#Correcion variable pol_centr_ext
datos_kaggle['pol_centr_ext'] = datos_kaggle['pol_centr_ext'].astype(float)
datos_kaggle.loc[datos_kaggle['pol_centr_ext'] >= 1 ,'pol_centr_ext'] = '1'

# %%
#Correccion variable convenio
datos_kaggle.loc[datos_kaggle['convenio_lib'].notnull(),'convenio_lib'] = 'SI'

# %%
#Correccion variable periodo oor PANDEMIA
datos_kaggle.loc[datos_kaggle['periodo'] <= 202003,'periodo'] = 0
datos_kaggle.loc[datos_kaggle['periodo'] > 202003,'periodo'] = 1

# %%
#Cambiar tipo de datos a las variables string
datos_kaggle['categoria'] = datos_kaggle['categoria'].astype('string')
datos_kaggle['genero'] = datos_kaggle['genero'].astype('string')
datos_kaggle['estado_civil']= datos_kaggle['estado_civil'].astype('string')
datos_kaggle['nivel_academico']= datos_kaggle['nivel_academico'].astype('string')
datos_kaggle['profesion']= datos_kaggle['profesion'].astype('string')
datos_kaggle['ocupacion']= datos_kaggle['ocupacion'].astype('string')
datos_kaggle['tipo_vivienda']= datos_kaggle['tipo_vivienda'].astype('string')
datos_kaggle['ind_mora_vigente'] = datos_kaggle['ind_mora_vigente'].astype('string')
datos_kaggle['cartera_castigada']= datos_kaggle['cartera_castigada'].astype('string')
datos_kaggle['ciudad_residencia']= datos_kaggle['ciudad_residencia'].astype('string')
datos_kaggle['ciudad_laboral']= datos_kaggle['ciudad_laboral'].astype('string')
datos_kaggle['departamento_residencia'] = datos_kaggle['departamento_residencia'].astype('string')
datos_kaggle['departamento_laboral'] = datos_kaggle['departamento_laboral'].astype('string')
datos_kaggle['rechazo_credito'] = datos_kaggle['rechazo_credito'].astype('string')
datos_kaggle['tenencia_tc'] = datos_kaggle['tenencia_tc'].astype('string')
datos_kaggle['tiene_consumo']  = datos_kaggle['tiene_consumo'].astype('string')
datos_kaggle['tiene_crediagil'] = datos_kaggle['tiene_crediagil'].astype('string')
datos_kaggle['tiene_ctas_activas'] = datos_kaggle['tiene_ctas_activas'].astype('string')
datos_kaggle['tiene_ctas_embargadas'] = datos_kaggle['tiene_ctas_embargadas'].astype('string')
datos_kaggle['pension_fopep'] = datos_kaggle['pension_fopep'].astype('string')
datos_kaggle['tiene_cred_hipo_1'] = datos_kaggle['tiene_cred_hipo_1'].astype('string')
datos_kaggle['tiene_cred_hipo_2'] = datos_kaggle['tiene_cred_hipo_2'].astype('string')
datos_kaggle['cat_ingreso'] = datos_kaggle['cat_ingreso'].astype('string')
datos_kaggle['rep_calif_cred'] = datos_kaggle['rep_calif_cred'].astype('string')
datos_kaggle['convenio_lib'] = datos_kaggle['convenio_lib'].astype('string')

# %%
#Cambiar tipo de datos a las variables numericas
datos_kaggle['edad'] = datos_kaggle['edad'].astype(float)
datos_kaggle['mora_max'] = datos_kaggle['mora_max'].astype(float)
datos_kaggle['cant_moras_30_ult_12_meses'] = datos_kaggle['cant_moras_30_ult_12_meses'].astype(float)
datos_kaggle['cant_moras_60_ult_12_meses'] = datos_kaggle['cant_moras_60_ult_12_meses'].astype(float)
datos_kaggle['cant_moras_90_ult_12_meses'] = datos_kaggle['cant_moras_90_ult_12_meses'].astype(float)
datos_kaggle['nro_tot_cuentas'] = datos_kaggle['nro_tot_cuentas'].astype(float)
datos_kaggle['ctas_activas'] = datos_kaggle['ctas_activas'].astype(float)
datos_kaggle['ctas_embargadas'] = datos_kaggle['ctas_embargadas'].astype(float)
datos_kaggle['ind'] = datos_kaggle['ind'].astype(float)
datos_kaggle['cuota_cred_hipot'] = datos_kaggle['cuota_cred_hipot'].astype(float)
datos_kaggle['ingreso_final'] = datos_kaggle['ingreso_final'].astype(float)
datos_kaggle['cant_mora_30_tdc_ult_3m_sf'] = datos_kaggle['cant_mora_30_tdc_ult_3m_sf'].astype(float)
datos_kaggle['cant_mora_30_consum_ult_3m_sf'] = datos_kaggle['cant_mora_30_consum_ult_3m_sf'].astype(float)
datos_kaggle['cant_oblig_tot_sf'] = datos_kaggle['cant_oblig_tot_sf'].astype(float)
datos_kaggle['cant_cast_ult_12m_sr'] = datos_kaggle['cant_cast_ult_12m_sr'].astype(float)
datos_kaggle['ingreso_nomina'] = datos_kaggle['ingreso_nomina'].astype(float)
datos_kaggle['ingreso_segurida_social'] = datos_kaggle['ingreso_segurida_social'].astype(float)

# %% [markdown]
# ###Imputación

# %%
#imputaciones con la moda (criterio: menos del 30% faltante)
datos_kaggle.loc[datos_kaggle['estado_civil'].isna() == True, 'estado_civil'] = datos_kaggle['estado_civil'].mode()[0]
datos_kaggle.loc[datos_kaggle['edad'].isna() == True, 'edad'] = datos_kaggle['edad'].mode()[0]
datos_kaggle.loc[datos_kaggle['nivel_academico'].isna() == True, 'nivel_academico'] = datos_kaggle['nivel_academico'].mode()[0]
datos_kaggle.loc[datos_kaggle['profesion'].isna() == True, 'profesion'] = datos_kaggle['profesion'].mode()[0]
datos_kaggle.loc[datos_kaggle['ocupacion'].isna() == True, 'ocupacion'] = datos_kaggle['ocupacion'].mode()[0]
datos_kaggle.loc[datos_kaggle['categoria'].isna() == True, 'categoria'] = datos_kaggle['categoria'].mode()[0]
datos_kaggle.loc[datos_kaggle['ind_mora_vigente'].isna() == True, 'ind_mora_vigente'] = datos_kaggle['ind_mora_vigente'].mode()[0]
datos_kaggle.loc[datos_kaggle['cartera_castigada'].isna() == True, 'cartera_castigada'] = datos_kaggle['cartera_castigada'].mode()[0]
datos_kaggle.loc[datos_kaggle['mora_max'].isna() == True, 'mora_max'] = datos_kaggle['mora_max'].mode()[0]
datos_kaggle.loc[datos_kaggle['cant_moras_30_ult_12_meses'].isna() == True, 'cant_moras_30_ult_12_meses'] = datos_kaggle['cant_moras_30_ult_12_meses'].mode()[0]
datos_kaggle.loc[datos_kaggle['cant_moras_60_ult_12_meses'].isna() == True, 'cant_moras_60_ult_12_meses'] = datos_kaggle['cant_moras_60_ult_12_meses'].mode()[0]
datos_kaggle.loc[datos_kaggle['cant_moras_90_ult_12_meses'].isna() == True, 'cant_moras_90_ult_12_meses'] = datos_kaggle['cant_moras_90_ult_12_meses'].mode()[0]
datos_kaggle.loc[datos_kaggle['nro_tot_cuentas'].isna() == True, 'nro_tot_cuentas'] = datos_kaggle['nro_tot_cuentas'].mode()[0]
datos_kaggle.loc[datos_kaggle['ctas_activas'].isna() == True, 'ctas_activas'] = datos_kaggle['ctas_activas'].mode()[0]
datos_kaggle.loc[datos_kaggle['tiene_ctas_activas'].isna() == True, 'tiene_ctas_activas'] = datos_kaggle['tiene_ctas_activas'].mode()[0]
datos_kaggle.loc[datos_kaggle['ctas_embargadas'].isna() == True, 'ctas_embargadas'] = datos_kaggle['ctas_embargadas'].mode()[0]
datos_kaggle.loc[datos_kaggle['ingreso_final'].isna() == True, 'ingreso_final'] = datos_kaggle['ingreso_final'].mode()[0]
datos_kaggle.loc[datos_kaggle['cant_mora_30_tdc_ult_3m_sf'].isna() == True, 'cant_mora_30_tdc_ult_3m_sf'] = datos_kaggle['cant_mora_30_tdc_ult_3m_sf'].mode()[0]
datos_kaggle.loc[datos_kaggle['cant_mora_30_consum_ult_3m_sf'].isna() == True, 'cant_mora_30_consum_ult_3m_sf'] = datos_kaggle['cant_mora_30_consum_ult_3m_sf'].mode()[0]
datos_kaggle.loc[datos_kaggle['cant_oblig_tot_sf'].isna() == True, 'cant_oblig_tot_sf'] = datos_kaggle['cant_oblig_tot_sf'].mode()[0]
datos_kaggle.loc[datos_kaggle['cant_cast_ult_12m_sr'].isna() == True, 'cant_cast_ult_12m_sr'] = datos_kaggle['cant_cast_ult_12m_sr'].mode()[0]
datos_kaggle.loc[datos_kaggle['ind'].isna() == True, 'ind'] = datos_kaggle['ind'].mode()[0]
datos_kaggle.loc[datos_kaggle['rep_calif_cred'].isna() == True, 'rep_calif_cred'] = datos_kaggle['rep_calif_cred'].mode()[0]
datos_kaggle.loc[datos_kaggle['pol_centr_ext'].isna() == True, 'pol_centr_ext'] = datos_kaggle['pol_centr_ext'].mode()[0]
datos_kaggle.loc[datos_kaggle['departamento_residencia'].isna() == True, 'departamento_residencia'] = datos_kaggle['departamento_residencia'].mode()[0]


#imputacion con una costante para flags y por su importancia
datos_kaggle.loc[datos_kaggle['tiene_consumo'].isna() == True, 'tiene_consumo'] = '-1'
datos_kaggle.loc[datos_kaggle['tiene_crediagil'].isna() == True, 'tiene_crediagil'] = '-1'
datos_kaggle.loc[datos_kaggle['tiene_ctas_embargadas'].isna() == True, 'tiene_ctas_embargadas'] = '-1'
datos_kaggle.loc[datos_kaggle['pension_fopep'].isna() == True, 'pension_fopep'] = '-1'
datos_kaggle.loc[datos_kaggle['cuota_cred_hipot'].isna() == True, 'cuota_cred_hipot'] = 0
datos_kaggle.loc[datos_kaggle['tiene_cred_hipo_1'].isna() == True, 'tiene_cred_hipo_1'] = '-1'
datos_kaggle.loc[datos_kaggle['tiene_cred_hipo_2'].isna() == True, 'tiene_cred_hipo_2'] = '-1'

#imputacion con la moda pero con altos valores faltantes e importancia. NOTA:pendiente si se imputan con KNN
datos_kaggle.loc[datos_kaggle['cat_ingreso'].isna() == True, 'cat_ingreso'] = datos_kaggle['cat_ingreso'].mode()[0]
datos_kaggle.loc[datos_kaggle['ingreso_nomina'].isna() == True, 'ingreso_nomina'] = datos_kaggle['ingreso_nomina'].mode()[0]
datos_kaggle.loc[datos_kaggle['ingreso_segurida_social'].isna() == True, 'ingreso_segurida_social'] = datos_kaggle['ingreso_segurida_social'].mode()[0]
datos_kaggle.loc[datos_kaggle['tipo_vivienda'].isna() == True, 'tipo_vivienda'] = datos_kaggle['tipo_vivienda'].mode()[0]

# %%
#Cambiar tipo de datos_kaggle a las variables string a Category
datos_kaggle['categoria'] = datos_kaggle['categoria'].astype('category')
datos_kaggle['genero'] = datos_kaggle['genero'].astype('category')
datos_kaggle['estado_civil']= datos_kaggle['estado_civil'].astype('category')
datos_kaggle['nivel_academico']= datos_kaggle['nivel_academico'].astype('category')
datos_kaggle['profesion']= datos_kaggle['profesion'].astype('category')
datos_kaggle['ocupacion']= datos_kaggle['ocupacion'].astype('category')
datos_kaggle['tipo_vivienda']= datos_kaggle['tipo_vivienda'].astype('category')
datos_kaggle['ind_mora_vigente'] = datos_kaggle['ind_mora_vigente'].astype('category')
datos_kaggle['cartera_castigada']= datos_kaggle['cartera_castigada'].astype('category')
datos_kaggle['departamento_residencia'] = datos_kaggle['departamento_residencia'].astype('category')

#Borradas en la imputacion
datos_kaggle['ciudad_residencia']= datos_kaggle['ciudad_residencia'].astype('category')
datos_kaggle['ciudad_laboral']= datos_kaggle['ciudad_laboral'].astype('category')
datos_kaggle['departamento_laboral'] = datos_kaggle['departamento_laboral'].astype('category')
datos_kaggle['convenio_lib'] = datos_kaggle['convenio_lib'].astype('category')

datos_kaggle['rechazo_credito'] = datos_kaggle['rechazo_credito'].astype('category')
datos_kaggle['tenencia_tc'] = datos_kaggle['tenencia_tc'].astype('category')
datos_kaggle['tiene_ctas_activas'] = datos_kaggle['tiene_ctas_activas'].astype('category')

#2da Iteracion
datos_kaggle['tiene_consumo']  = datos_kaggle['tiene_consumo'].astype('category')
datos_kaggle['tiene_crediagil'] = datos_kaggle['tiene_crediagil'].astype('category')
datos_kaggle['tiene_ctas_embargadas'] = datos_kaggle['tiene_ctas_embargadas'].astype('category')
datos_kaggle['pension_fopep'] = datos_kaggle['pension_fopep'].astype('category')
datos_kaggle['tiene_cred_hipo_1'] = datos_kaggle['tiene_cred_hipo_1'].astype('category')
datos_kaggle['tiene_cred_hipo_2'] = datos_kaggle['tiene_cred_hipo_2'].astype('category')


datos_kaggle['cat_ingreso'] = datos_kaggle['cat_ingreso'].astype('category')
datos_kaggle['rep_calif_cred'] = datos_kaggle['rep_calif_cred'].astype('category')

# %% [markdown]
# ###Descarga

# %%
#Guardar los datos de test limpios
datos_kaggle.to_csv('/content/drive/MyDrive/DATATON/Dataset_limpios/test_limpio.csv')
